# %% [markdown]
# # Урок 3. Системы управления базами данных MongoDB и SQLite в Python
# 1) Развернуть у себя на компьютере/виртуальной машине/хостинге MongoDB и реализовать функцию, записывающую собранные вакансии в созданную БД (без датафрейма)
#
# 2) Написать функцию, которая производит поиск и выводит на экран вакансии с заработной платой больше введенной суммы. Поиск по двум полям (мин и макс зарплату)
#
# 3) Написать функцию, которая будет добавлять в вашу базу данных только новые вакансии с сайта

# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
from pprint import pprint
import re

# %%
def preporation_parser(vacancy):
    vacancys = []
    
    params = {
        'text': vacancy, \
        'search_field': "name", \
        'page': ''
    }
    
    headers = {
        'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko)'
    }
    
    link = 'https://hh.ru/search/vacancy' 
    html = requests.get(link, params=params, headers=headers)
    
    if html.ok:
        parsed_html = bs(html.text,'html.parser')
        
        page_block = parsed_html.find('div', {'data-qa': 'pager-next'})
        
        if html.ok:
            parsed_html = bs(html.text,'html.parser')
            
            vacancy_items = parsed_html.find('div', {'class': 'vacancy-serp'}).find_all('div',{'class':'vacancy-serp-item'})
                
            for item in vacancy_items:
                vacancys.append(parser_hh(item))
    #pprint(vacancy_date)            
    return len(vacancys)

# %%
def parser_hh(item):
    vacancy_date = {}
    
    # vacancy name
    vacancy_name = item.find('div',{'class':'vacancy-serp-item__info'}).getText().replace(u'\xa0', u' ')
    vacancy_date['name'] = vacancy_name
    
    # company_name
    company_name = item.find('div',{'class':'vacancy-serp-item__meta-info'}).find('a').getText()
    vacancy_date['company_name'] = company_name
    
    # city 
    city = item.find('span',{'data-qa':'vacancy-serp__vacancy-address'}).getText()
    vacancy_date['city'] = city
    
    # salary
    
    salary = item.find('div',{'class':'vacancy-serp-item__sidebar'})
    if not salary:
        salary_min = None
        salary_max = None
        salary_currency = None
    else:
        salary = salary.getText() \
                        .replace(u'\xa0', u'')
        
        salary = re.split(r'\s|-', salary)
        
        if salary[0] == 'до':
            salary_min = None
            salary_max = int(salary[1])
            salary_currency = salary[2]
        elif salary[0] == 'от':
            salary_min = int(salary[1])
            salary_max = None
            salary_currency = salary[2]
        elif salary[0] == '':
            salary_min = None
            salary_max = None
            salary_currency = None
            salary_currency = None
        else:
            salary_min = int(salary[0])
            salary_max = int(salary[1])
            salary_currency = salary[2]
        
        
        
    vacancy_date['salary_min'] = salary_min
    vacancy_date['salary_max'] = salary_max
    vacancy_date['salary_currency'] = salary_currency
    
    # link
    vacancy_link = item.find('a',{'class':'bloko-link'})['href']
    vacancy_date['link'] = vacancy_link
    
    # id 
    vacancy_pred_id = 1
    vacancy_id = int(re.findall(r'\d+', vacancy_link)[0])
    vacancy_date['_id'] = vacancy_id
        
    vacancy_date['_id'] = vacancy_id
    
    # site
    vacancy_date['site'] = 'hh.ru'
    
    
    return vacancy_date

# %%
from pymongo import MongoClient
from pymongo.errors import BulkWriteError

# %%
job = input('Вакансия: ')
salary = input('Зарплата: ')
# Out:
# Вакансия: python
# Зарплата: 5000000

# %%
# клиент для подключения к серверу
client = MongoClient('localhost', 27017)

# %%
db = client['my_database']

# %% [markdown]
# Развернуть у себя на компьютере/виртуальной машине/хостинге MongoDB и реализовать функцию, записывающую собранные вакансии в созданную БД (без датафрейма)

# %%
vacancys_data = preporation_parser(job)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-297-7af3435be7f9> in <module>
# ----> 1 vacancys_data = preporation_parser(job)
#
# <ipython-input-295-47f1520f1845> in preporation_parser(vacancy)
#      24             last_page = int(page_block.find_all('a', {'data-qa': 'pager-page'}).getText())
#      25
# ---> 26     for page in range(0, last_page):
#      27         params['page'] = page
#      28         html = requests.get(link, params=params, headers=headers)
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
pprint(vacancys_data)

# %%
def write_vacancys(vacancys_date):
    # создаю коллекцию вакансий
    vacancys = db.vacancys
    
    vacancys.insert_many(vacancys_date)
    #vacancys.delete_many({})
     
    #return vacancys
    for vacancy in vacancys.find({}):
        pprint(vacancy)

# %%
write_vacancys(vacancys_data)
# Out:
# ---------------------------------------------------------------------------
# BulkWriteError                            Traceback (most recent call last)
# <ipython-input-198-90ec24fe5ad5> in <module>
# ----> 1 write_vacancys(vacancys_data)
#
# <ipython-input-197-50edee92a354> in write_vacancys(vacancys_date)
#       3     vacancys = db.vacancys
#       4
# ----> 5     vacancys.insert_many(vacancys_date)
#       6     #vacancys.delete_many({})
#       7
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pymongo/collection.py in insert_many(self, documents, ordered, bypass_document_validation, session)
#     756         blk = _Bulk(self, ordered, bypass_document_validation)
#     757         blk.ops = [doc for doc in gen()]
# --> 758         blk.execute(write_concern, session=session)
#     759         return InsertManyResult(inserted_ids, write_concern.acknowledged)
#     760
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pymongo/bulk.py in execute(self, write_concern, session)
#     509                 self.execute_no_results(sock_info, generator)
#     510         else:
# --> 511             return self.execute_command(generator, write_concern, session)
#     512
#     513
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pymongo/bulk.py in execute_command(self, generator, write_concern, session)
#     347
#     348         if full_result["writeErrors"] or full_result["writeConcernErrors"]:
# --> 349             _raise_bulk_write_error(full_result)
#     350         return full_result
#     351
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pymongo/bulk.py in _raise_bulk_write_error(full_result)
#     138         full_result["writeErrors"].sort(
#     139             key=lambda error: error["index"])
# --> 140     raise BulkWriteError(full_result)
#     141
#     142
#
# BulkWriteError: batch op errors occurred

# %% [markdown]
# 2) Написать функцию, которая производит поиск и выводит на экран вакансии с заработной платой больше введенной суммы. Поиск по двум полям (мин и макс зарплату)

# %%
def find_vacancy_by_salary(salary, vacancys_data):
    ''' Функция вывода вакансий с определенной заработной платой
        Если зарплата больше той, что ввел пользователь,
        то выведем такую вакансию.'''
    
    write_vacancys(vacancys_data)
    vacancys_salary_more = vacancys.find({'$or':[{'salary_min':{'$gt':salary}}, {'salary_max':{'$gt':salary}}]})
    
    return vacancys_salary_more

# %%
find_vacancy_by_salary(salary, vacancys_data)
# Out:
# {'_id': ObjectId('5efed56ac4bfbb6ef57a351c'),
#  'city': 'Москва',
#  'company_name': ' CATAPULTO.RU',
#  'link': 'https://krasnodar.hh.ru/vacancy/37674249?query=python',
#  'name': 'Программист-разработчик python (midle)',
#  'salary_currency': 'руб.',
#  'salary_max': '180000',
#  'salary_min': '100000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a351d'),
#  'city': 'Санкт-Петербург, Петроградская',
#  'company_name': ' Интеллектуальные системы',
#  'link': 'https://krasnodar.hh.ru/vacancy/37765447?query=python',
#  'name': 'Скилловый Python Developer на бэкенд',
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': '250000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a351e'),
#  'city': 'Москва',
#  'company_name': 'ООО Чистый Маркетинг',
#  'link': 'https://krasnodar.hh.ru/vacancy/37461514?query=python',
#  'name': 'Python / Django fullstack программист',
#  'salary_currency': 'руб.',
#  'salary_max': '180000',
#  'salary_min': '110000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a351f'),
#  'city': 'Минск',
#  'company_name': ' Scand',
#  'link': 'https://krasnodar.hh.ru/vacancy/37792411?query=python',
#  'name': 'Python Developer',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3520'),
#  'city': 'Минск',
#  'company_name': ' Scand',
#  'link': 'https://krasnodar.hh.ru/vacancy/37793827?query=python',
#  'name': 'Backend Python Engineer',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3521'),
#  'city': 'Москва',
#  'company_name': ' Infatica Pte Ltd',
#  'link': 'https://krasnodar.hh.ru/vacancy/37742512?query=python',
#  'name': 'Backend разработчик Python (Middle, Senior)',
#  'salary_currency': 'руб.',
#  'salary_max': '120000',
#  'salary_min': '80000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3522'),
#  'city': 'Минск, Немига',
#  'company_name': 'ООО IHS Global',
#  'link': 'https://krasnodar.hh.ru/vacancy/37762953?query=python',
#  'name': 'Senior Data Engineer / Python',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3523'),
#  'city': 'Минск',
#  'company_name': 'УП Руна Системс',
#  'link': 'https://krasnodar.hh.ru/vacancy/35095020?query=python',
#  'name': 'Senior Python Developer',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3524'),
#  'city': 'Москва',
#  'company_name': ' МФТИ ГУ',
#  'link': 'https://krasnodar.hh.ru/vacancy/37673701?query=python',
#  'name': 'Программист на Python / С++',
#  'salary_currency': 'руб.',
#  'salary_max': '180000',
#  'salary_min': '140000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3525'),
#  'city': 'Санкт-Петербург',
#  'company_name': 'ООО Софтвайс',
#  'link': 'https://krasnodar.hh.ru/vacancy/37603927?query=python',
#  'name': 'Аналитик данных / Data Analyst (Python/R)',
#  'salary_currency': 'руб.',
#  'salary_max': '175000',
#  'salary_min': '116000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3526'),
#  'city': 'Санкт-Петербург',
#  'company_name': ' Vilesse',
#  'link': 'https://krasnodar.hh.ru/vacancy/37394225?query=python',
#  'name': 'Разработчик Python',
#  'salary_currency': 'руб.',
#  'salary_max': '200000',
#  'salary_min': '150000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3527'),
#  'city': 'Москва, Румянцево',
#  'company_name': 'ООО Доверенная среда',
#  'link': 'https://krasnodar.hh.ru/vacancy/37565167?query=python',
#  'name': 'Программист Python',
#  'salary_currency': 'руб.',
#  'salary_max': '200000',
#  'salary_min': '160000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3528'),
#  'city': 'Москва',
#  'company_name': 'АО Интегрис',
#  'link': 'https://krasnodar.hh.ru/vacancy/37184106?query=python',
#  'name': 'Программист C++/Python',
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': '140000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3529'),
#  'city': 'Москва, Площадь Революции и еще 3 ',
#  'company_name': ' Web Interactive World',
#  'link': 'https://krasnodar.hh.ru/vacancy/37521387?query=python',
#  'name': 'Python Data Scientist',
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': '150000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a352a'),
#  'city': 'Екатеринбург',
#  'company_name': ' Vostok Projects',
#  'link': 'https://krasnodar.hh.ru/vacancy/37777964?query=python',
#  'name': 'Back-end разработчик (Python)',
#  'salary_currency': 'руб.',
#  'salary_max': '180000',
#  'salary_min': '100000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a352b'),
#  'city': 'Красноярск',
#  'company_name': 'ООО ЭКСПЕРТ-ПРО',
#  'link': 'https://krasnodar.hh.ru/vacancy/37576697?query=python',
#  'name': 'Python (Django) программист Junior',
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': '25000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a352c'),
#  'city': 'Москва, Бауманская',
#  'company_name': 'ООО БОЛЬШАЯ ТРОЙКА',
#  'link': 'https://krasnodar.hh.ru/vacancy/37587367?query=python',
#  'name': 'Backend python/Django разработчик',
#  'salary_currency': 'руб.',
#  'salary_max': '200000',
#  'salary_min': '120000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a352d'),
#  'city': 'Москва',
#  'company_name': ' ДВ технологии',
#  'link': 'https://krasnodar.hh.ru/vacancy/37500874?query=python',
#  'name': 'Python разработчик/программист (Junior/Middle Quantitative Python '
#          'Developer)',
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': '80000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a352e'),
#  'city': 'Москва, Деловой центр',
#  'company_name': 'ООО Смартекс',
#  'link': 'https://krasnodar.hh.ru/vacancy/36876631?query=python',
#  'name': 'Разработчик Python / Django',
#  'salary_currency': 'руб.',
#  'salary_max': '200000',
#  'salary_min': '150000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a352f'),
#  'city': 'Москва',
#  'company_name': ' Йенго РУ',
#  'link': 'https://krasnodar.hh.ru/vacancy/37522527?query=python',
#  'name': 'Разработчик Python',
#  'salary_currency': 'руб.',
#  'salary_max': '170000',
#  'salary_min': '150000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3530'),
#  'city': 'Москва',
#  'company_name': ' ОГО! онлайн-гипермаркет',
#  'link': 'https://krasnodar.hh.ru/vacancy/37698711?query=python',
#  'name': 'Backend разработчик на python',
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': '100000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3531'),
#  'city': 'Москва',
#  'company_name': ' КЭЛС-центр',
#  'link': 'https://krasnodar.hh.ru/vacancy/37625285?query=python',
#  'name': 'Разработчик Python',
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': '110000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3532'),
#  'city': 'Москва',
#  'company_name': 'ООО Энтропия',
#  'link': 'https://krasnodar.hh.ru/vacancy/37524910?query=python',
#  'name': 'Python разработчик',
#  'salary_currency': 'руб.',
#  'salary_max': '120000',
#  'salary_min': '100000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3533'),
#  'city': 'Москва, Красносельская',
#  'company_name': 'ООО Константа',
#  'link': 'https://krasnodar.hh.ru/vacancy/37483469?query=python',
#  'name': 'Python разработчик',
#  'salary_currency': 'руб.',
#  'salary_max': '220000',
#  'salary_min': '150000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3534'),
#  'city': 'Санкт-Петербург',
#  'company_name': ' Emphasoft',
#  'link': 'https://krasnodar.hh.ru/vacancy/36774670?query=python',
#  'name': 'Начинающий backend-разработчик (Python)',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3535'),
#  'city': 'Москва',
#  'company_name': 'ООО КИБЕРТОНИКА',
#  'link': 'https://krasnodar.hh.ru/vacancy/37642402?query=python',
#  'name': 'Python Backend Developer',
#  'salary_currency': 'руб.',
#  'salary_max': '160000',
#  'salary_min': '110000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3536'),
#  'city': 'Краснодар',
#  'company_name': ' B2Broker Санкт-Петербург',
#  'link': 'https://krasnodar.hh.ru/vacancy/37227093?query=python',
#  'name': 'Python developer удаленно',
#  'salary_currency': 'руб.',
#  'salary_max': '200000',
#  'salary_min': '150000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3537'),
#  'city': 'Москва, Сокол',
#  'company_name': ' Мясоперерабатывающий холдинг АРГО',
#  'link': 'https://krasnodar.hh.ru/vacancy/37402770?query=python',
#  'name': 'Программист Python',
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': '150000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3538'),
#  'city': 'Москва',
#  'company_name': ' Vilesse',
#  'link': 'https://krasnodar.hh.ru/vacancy/37415007?query=python',
#  'name': 'Разработчик Python',
#  'salary_currency': 'руб.',
#  'salary_max': '200000',
#  'salary_min': '150000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3539'),
#  'city': 'Алматы',
#  'company_name': 'ТОО AVIATA.KZ',
#  'link': 'https://krasnodar.hh.ru/vacancy/37564858?query=python',
#  'name': 'Backend Python Developer',
#  'salary_currency': 'KZT',
#  'salary_max': '750000',
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a353a'),
#  'city': 'Москва, Павелецкая',
#  'company_name': 'ООО Эктострой',
#  'link': 'https://krasnodar.hh.ru/vacancy/37641098?query=python',
#  'name': 'Backend-разработчик / Python developer',
#  'salary_currency': 'руб.',
#  'salary_max': '135000',
#  'salary_min': '70000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a353b'),
#  'city': 'Санкт-Петербург, Петроградская',
#  'company_name': ' B2Broker Санкт-Петербург',
#  'link': 'https://krasnodar.hh.ru/vacancy/37227041?query=python',
#  'name': 'Python developer удаленно',
#  'salary_currency': 'руб.',
#  'salary_max': '200000',
#  'salary_min': '150000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a353c'),
#  'city': 'Санкт-Петербург, Чкаловская',
#  'company_name': ' Digital Security',
#  'link': 'https://krasnodar.hh.ru/vacancy/37571622?query=python',
#  'name': 'Python-разработчик системы защиты',
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': '150000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a353d'),
#  'city': 'Томск',
#  'company_name': ' B2Broker Санкт-Петербург',
#  'link': 'https://krasnodar.hh.ru/vacancy/37227127?query=python',
#  'name': 'Python developer (удаленно)',
#  'salary_currency': 'руб.',
#  'salary_max': '200000',
#  'salary_min': '150000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a353e'),
#  'city': 'Москва, Багратионовская и еще 1 ',
#  'company_name': 'ООО Флайдата',
#  'link': 'https://krasnodar.hh.ru/vacancy/37619878?query=python',
#  'name': 'Backend разработчик (Python)',
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': '130000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a353f'),
#  'city': 'Екатеринбург',
#  'company_name': ' B2Broker Санкт-Петербург',
#  'link': 'https://krasnodar.hh.ru/vacancy/37227103?query=python',
#  'name': 'Python developer удаленно',
#  'salary_currency': 'руб.',
#  'salary_max': '200000',
#  'salary_min': '150000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3540'),
#  'city': 'Санкт-Петербург, Петроградская',
#  'company_name': ' B2Broker Санкт-Петербург',
#  'link': 'https://krasnodar.hh.ru/vacancy/36267290?query=python',
#  'name': 'Python developer',
#  'salary_currency': 'руб.',
#  'salary_max': '200000',
#  'salary_min': '150000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3541'),
#  'city': 'Новосибирск',
#  'company_name': ' B2Broker Санкт-Петербург',
#  'link': 'https://krasnodar.hh.ru/vacancy/37227109?query=python',
#  'name': 'Python developer (удаленно)',
#  'salary_currency': 'руб.',
#  'salary_max': '200000',
#  'salary_min': '150000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3542'),
#  'city': 'Москва, Деловой центр и еще 2 ',
#  'company_name': ' B2Broker Москва',
#  'link': 'https://krasnodar.hh.ru/vacancy/36267171?query=python',
#  'name': 'Python developer',
#  'salary_currency': 'руб.',
#  'salary_max': '200000',
#  'salary_min': '150000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3543'),
#  'city': 'Москва',
#  'company_name': ' BestDoctor',
#  'link': 'https://krasnodar.hh.ru/vacancy/36449432?query=python',
#  'name': 'Python middle developer',
#  'salary_currency': 'руб.',
#  'salary_max': '160000',
#  'salary_min': '120000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3544'),
#  'city': 'Ростов-на-Дону',
#  'company_name': 'ЗАО НОРСИ-ТРАНС',
#  'link': 'https://krasnodar.hh.ru/vacancy/36742022?query=python',
#  'name': 'C++/python разработчик',
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': '100000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3545'),
#  'city': 'Санкт-Петербург',
#  'company_name': ' Redsteep',
#  'link': 'https://krasnodar.hh.ru/vacancy/36160021?query=python',
#  'name': 'Senior Python разработчик',
#  'salary_currency': 'руб.',
#  'salary_max': '200000',
#  'salary_min': '150000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3546'),
#  'city': 'Москва',
#  'company_name': ' RESURS',
#  'link': 'https://krasnodar.hh.ru/vacancy/36872662?query=python',
#  'name': 'Разработчик (программист) Python (удаленно)',
#  'salary_currency': 'руб.',
#  'salary_max': '80000',
#  'salary_min': '60000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3547'),
#  'city': 'Воронеж',
#  'company_name': 'ООО Эктострой',
#  'link': 'https://krasnodar.hh.ru/vacancy/37389795?query=python',
#  'name': 'Backend-разработчик / Python developer',
#  'salary_currency': 'руб.',
#  'salary_max': '135000',
#  'salary_min': '70000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3548'),
#  'city': 'Москва, Дмитровская',
#  'company_name': 'ООО Хантфлоу',
#  'link': 'https://krasnodar.hh.ru/vacancy/37547995?query=python',
#  'name': 'Python Developer',
#  'salary_currency': 'руб.',
#  'salary_max': '150000',
#  'salary_min': '120000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3549'),
#  'city': 'Москва',
#  'company_name': 'ЗАО Геоцентр-Консалтинг',
#  'link': 'https://krasnodar.hh.ru/vacancy/37406327?query=python',
#  'name': 'ГИС-технолог (Python)',
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': '80000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a354a'),
#  'city': 'Челябинск',
#  'company_name': 'ООО Прикладные технологии',
#  'link': 'https://krasnodar.hh.ru/vacancy/36541868?query=python',
#  'name': 'Программист Python',
#  'salary_currency': 'руб.',
#  'salary_max': '150000',
#  'salary_min': '100000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a354b'),
#  'city': 'Екатеринбург, Динамо',
#  'company_name': 'ООО Прикладные технологии',
#  'link': 'https://krasnodar.hh.ru/vacancy/36541983?query=python',
#  'name': 'Программист Python',
#  'salary_currency': 'руб.',
#  'salary_max': '150000',
#  'salary_min': '100000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a354c'),
#  'city': 'Москва',
#  'company_name': ' Нетамс',
#  'link': 'https://krasnodar.hh.ru/vacancy/37719119?query=python',
#  'name': 'Программист Python',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a354d'),
#  'city': 'Санкт-Петербург',
#  'company_name': ' Spark Equation',
#  'link': 'https://krasnodar.hh.ru/vacancy/37642858?query=python',
#  'name': 'Python Lead Engineer',
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': '210000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a354e'),
#  'city': 'Москва',
#  'company_name': ' BestDoctor',
#  'link': 'https://krasnodar.hh.ru/vacancy/37115745?query=python',
#  'name': 'Python senior developer',
#  'salary_currency': 'руб.',
#  'salary_max': '250000',
#  'salary_min': '180000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a354f'),
#  'city': 'Санкт-Петербург, Чкаловская',
#  'company_name': ' Karuna',
#  'link': 'https://krasnodar.hh.ru/vacancy/37731951?query=python',
#  'name': 'Python Developer',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3550'),
#  'city': 'Москва, Калужская',
#  'company_name': 'ООО ИДАГРУПП',
#  'link': 'https://krasnodar.hh.ru/vacancy/37719390?query=python',
#  'name': 'Python/Django разработчик',
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': '70000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3551'),
#  'city': 'Москва, Сухаревская',
#  'company_name': 'ООО Фабрика Решений',
#  'link': 'https://krasnodar.hh.ru/vacancy/37570004?query=python',
#  'name': 'Python-разработчик (Django, DRF)',
#  'salary_currency': 'руб.',
#  'salary_max': '150000',
#  'salary_min': '60000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3552'),
#  'city': 'Санкт-Петербург',
#  'company_name': ' First_Line',
#  'link': 'https://krasnodar.hh.ru/vacancy/37537946?query=python',
#  'name': 'Senior Python developer',
#  'salary_currency': 'руб.',
#  'salary_max': '220000',
#  'salary_min': '160000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3553'),
#  'city': 'Санкт-Петербург, Василеостровская и еще 2 ',
#  'company_name': 'ООО СЗ РЦАИ',
#  'link': 'https://krasnodar.hh.ru/vacancy/37635703?query=python',
#  'name': 'GIS Engineer / Python Developer',
#  'salary_currency': 'руб.',
#  'salary_max': '80000',
#  'salary_min': '60000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3554'),
#  'city': 'Москва',
#  'company_name': ' evrone.ru',
#  'link': 'https://krasnodar.hh.ru/vacancy/37788379?query=python',
#  'name': 'Python developer',
#  'salary_currency': 'руб.',
#  'salary_max': '200000',
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3555'),
#  'city': 'Москва, Марьина Роща и еще 1 ',
#  'company_name': ' ЭргоСОЛО',
#  'link': 'https://krasnodar.hh.ru/vacancy/37757725?query=python',
#  'name': 'Web-разработчик на Python',
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': '140000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3556'),
#  'city': 'Москва, Алексеевская',
#  'company_name': 'АО Научно-исследовательский институт железнодорожного '
#                  'транспорта',
#  'link': 'https://krasnodar.hh.ru/vacancy/37524167?query=python',
#  'name': 'Программист Python',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3557'),
#  'city': 'Москва',
#  'company_name': 'ООО Технологии продаж',
#  'link': 'https://krasnodar.hh.ru/vacancy/37707623?query=python',
#  'name': 'Middle python разработчик (удаленная работа)',
#  'salary_currency': 'руб.',
#  'salary_max': '100000',
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3558'),
#  'city': 'Москва, Киевская',
#  'company_name': ' ИТЕРАНЕТ',
#  'link': 'https://krasnodar.hh.ru/vacancy/37784877?query=python',
#  'name': 'Разработчик Python',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3559'),
#  'city': 'Москва, Комсомольская и еще 2 ',
#  'company_name': ' PARATON',
#  'link': 'https://krasnodar.hh.ru/vacancy/37798101?query=python',
#  'name': 'Full-Stack developer (Js / Python)',
#  'salary_currency': 'руб.',
#  'salary_max': '200000',
#  'salary_min': '100000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a355a'),
#  'city': 'Москва, Павелецкая',
#  'company_name': 'ООО Телеформ ИС',
#  'link': 'https://krasnodar.hh.ru/vacancy/37681977?query=python',
#  'name': 'Python Developer',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a355b'),
#  'city': 'Саранск',
#  'company_name': ' EventPlatform',
#  'link': 'https://krasnodar.hh.ru/vacancy/37485420?query=python',
#  'name': 'Разработчик Python',
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': '45000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a355c'),
#  'city': 'Москва',
#  'company_name': ' Betby',
#  'link': 'https://krasnodar.hh.ru/vacancy/37740511?query=python',
#  'name': 'Senior Python Developer (to Riga)',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a355d'),
#  'city': 'Москва, Калужская',
#  'company_name': 'ООО Соушиал Линкс',
#  'link': 'https://krasnodar.hh.ru/vacancy/37490232?query=python',
#  'name': 'Разработчик Python',
#  'salary_currency': 'руб.',
#  'salary_max': '80000',
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a355e'),
#  'city': 'Санкт-Петербург, Площадь Александра Невского 1',
#  'company_name': 'ООО Аксиома',
#  'link': 'https://krasnodar.hh.ru/vacancy/37446940?query=python',
#  'name': 'Python Full-stack developer Senior',
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': '160000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a355f'),
#  'city': 'Санкт-Петербург, Балтийская',
#  'company_name': 'ООО Глассен-АйТи',
#  'link': 'https://krasnodar.hh.ru/vacancy/37440265?query=python',
#  'name': 'Python-разработчик',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3560'),
#  'city': 'Москва, Автозаводская',
#  'company_name': 'ООО НТ Прогресс',
#  'link': 'https://krasnodar.hh.ru/vacancy/35871016?query=python',
#  'name': 'Разработчик Python',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3561'),
#  'city': 'Санкт-Петербург',
#  'company_name': 'ООО АвтоЭксперт',
#  'link': 'https://krasnodar.hh.ru/vacancy/37386936?query=python',
#  'name': 'Senior Python-разработчик',
#  'salary_currency': 'руб.',
#  'salary_max': '200000',
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3562'),
#  'city': 'Москва',
#  'company_name': 'ООО Байтверк РУС',
#  'link': 'https://krasnodar.hh.ru/vacancy/37465084?query=python',
#  'name': 'Программист Verilog / C / Python (проект FPGA HSM)',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3563'),
#  'city': 'Москва, Кутузовская',
#  'company_name': ' ДомКлик',
#  'link': 'https://krasnodar.hh.ru/vacancy/37748451?query=python',
#  'name': 'Разработчик Python',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3564'),
#  'city': 'Санкт-Петербург',
#  'company_name': 'АО НИК',
#  'link': 'https://krasnodar.hh.ru/vacancy/37345727?query=python',
#  'name': 'Python developer / Python разработчик',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3565'),
#  'city': 'Москва',
#  'company_name': ' DEEP & HARD',
#  'link': 'https://krasnodar.hh.ru/vacancy/37403087?query=python',
#  'name': 'Backend Developer (python/go, Удалённо)',
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': '160000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3566'),
#  'city': 'Тольятти',
#  'company_name': ' kt.team',
#  'link': 'https://krasnodar.hh.ru/vacancy/37667534?query=python',
#  'name': 'Backend-разработчик (PHP, Node.js, Go, Python)',
#  'salary_currency': 'руб.',
#  'salary_max': '180000',
#  'salary_min': '40000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3567'),
#  'city': 'Калининград',
#  'company_name': 'ООО «Инносети»',
#  'link': 'https://krasnodar.hh.ru/vacancy/37597881?query=python',
#  'name': 'Backend-разработчик (Python)',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3568'),
#  'city': 'Москва, Менделеевская и еще 1 ',
#  'company_name': 'ООО ЭНГРИ',
#  'link': 'https://krasnodar.hh.ru/vacancy/37312749?query=python',
#  'name': 'Middle/Senior python developer',
#  'salary_currency': 'руб.',
#  'salary_max': '200000',
#  'salary_min': '120000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3569'),
#  'city': 'Санкт-Петербург, Спортивная',
#  'company_name': 'ООО ВЕБИМ.РУ',
#  'link': 'https://krasnodar.hh.ru/vacancy/37580721?query=python',
#  'name': 'Начинающий python backend разработчик',
#  'salary_currency': 'руб.',
#  'salary_max': '40000',
#  'salary_min': '25000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a356a'),
#  'city': 'Санкт-Петербург, Елизаровская и еще 2 ',
#  'company_name': 'ООО Ю.Би.Си',
#  'link': 'https://krasnodar.hh.ru/vacancy/37802754?query=python',
#  'name': 'Разработчик программист C++, Python, PHP',
#  'salary_currency': 'руб.',
#  'salary_max': '200000',
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a356b'),
#  'city': 'Санкт-Петербург',
#  'company_name': ' First_Line',
#  'link': 'https://krasnodar.hh.ru/vacancy/37581193?query=python',
#  'name': 'Middle Python developer',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a356c'),
#  'city': 'Москва, Калужская',
#  'company_name': ' AERODISK',
#  'link': 'https://krasnodar.hh.ru/vacancy/37554152?query=python',
#  'name': 'Python Back-end разработчик',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a356d'),
#  'city': 'Москва',
#  'company_name': 'ООО Основа Лаб',
#  'link': 'https://krasnodar.hh.ru/vacancy/37169502?query=python',
#  'name': 'Инженер по автоматизации тестирования / Python разработчик',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a356e'),
#  'city': 'Нижний Новгород, Горьковская',
#  'company_name': ' Meriterra',
#  'link': 'https://krasnodar.hh.ru/vacancy/37566005?query=python',
#  'name': 'Python Developer',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a356f'),
#  'city': 'Москва',
#  'company_name': ' ДВ технологии',
#  'link': 'https://krasnodar.hh.ru/vacancy/37500870?query=python',
#  'name': 'Python разработчик/программист (Middle Python Developer)',
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': '135000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3570'),
#  'city': 'Минск',
#  'company_name': 'ООО Фреш Лайм Софт',
#  'link': 'https://krasnodar.hh.ru/vacancy/37645071?query=python',
#  'name': 'Junior Full-Stack Developer (PHP, Laravel, Symfony, Yii, Code '
#          'Igniter, Zend, Python, Django)',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3571'),
#  'city': 'Минск',
#  'company_name': 'ООО Он Зэ Спот Девелопмент',
#  'link': 'https://krasnodar.hh.ru/vacancy/37658579?query=python',
#  'name': 'Python Data Engineer',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3572'),
#  'city': 'Новосибирск, Маршала Покрышкина',
#  'company_name': ' НЛ Континент',
#  'link': 'https://krasnodar.hh.ru/vacancy/37672059?query=python',
#  'name': 'Программист Python Developer',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3573'),
#  'city': 'Москва, Менделеевская и еще 2 ',
#  'company_name': ' ИнПлат',
#  'link': 'https://krasnodar.hh.ru/vacancy/36711877?query=python',
#  'name': 'Разработчик Python',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3574'),
#  'city': 'Москва, Третьяковская и еще 2 ',
#  'company_name': ' Deutsche Bank Technology Center',
#  'link': 'https://krasnodar.hh.ru/vacancy/37372568?query=python',
#  'name': 'Senior Python developer (RiskEngine)',
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': '220000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3575'),
#  'city': 'Москва, Марьина Роща и еще 1 ',
#  'company_name': ' NVIDIA',
#  'link': 'https://krasnodar.hh.ru/vacancy/36922412?query=python',
#  'name': 'GFN Software Engineer - Gaming (Python, C++)',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3576'),
#  'city': 'Москва, Улица 1905 года',
#  'company_name': ' Quiet Media',
#  'link': 'https://krasnodar.hh.ru/vacancy/37436374?query=python',
#  'name': 'Senior Python разработчик',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3577'),
#  'city': 'Москва',
#  'company_name': 'ООО НТБ',
#  'link': 'https://krasnodar.hh.ru/vacancy/37413096?query=python',
#  'name': 'Программист Python',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3578'),
#  'city': 'Санкт-Петербург',
#  'company_name': ' Spark Equation',
#  'link': 'https://krasnodar.hh.ru/vacancy/37661352?query=python',
#  'name': 'Senior Python Engineer',
#  'salary_currency': 'руб.',
#  'salary_max': '210000',
#  'salary_min': '160000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3579'),
#  'city': 'Москва, Дмитровская и еще 2 ',
#  'company_name': ' NGENIX',
#  'link': 'https://krasnodar.hh.ru/vacancy/36886946?query=python',
#  'name': 'Разработчик / Инженер-программист (Python)',
#  'salary_currency': 'руб.',
#  'salary_max': '230000',
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a357a'),
#  'city': 'Минск',
#  'company_name': 'ООО ИНСИДЭВ',
#  'link': 'https://krasnodar.hh.ru/vacancy/37484492?query=python',
#  'name': 'Middle Python Developer',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a357b'),
#  'city': 'Санкт-Петербург, Лесная',
#  'company_name': ' NGENIX',
#  'link': 'https://krasnodar.hh.ru/vacancy/36970511?query=python',
#  'name': 'Разработчик / Инженер-программист (Python)',
#  'salary_currency': 'руб.',
#  'salary_max': '200000',
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a357c'),
#  'city': 'Москва, Тульская',
#  'company_name': 'ООО Айтаргет',
#  'link': 'https://krasnodar.hh.ru/vacancy/37765730?query=python',
#  'name': 'Middle / Senior Python разработчик',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a357d'),
#  'city': 'Москва',
#  'company_name': 'ООО Когнитивные системы',
#  'link': 'https://krasnodar.hh.ru/vacancy/37796817?query=python',
#  'name': 'Python Developer/Team-lead',
#  'salary_currency': 'руб.',
#  'salary_max': '250',
#  'salary_min': '150',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a357e'),
#  'city': 'Москва, Шоссе Энтузиастов',
#  'company_name': ' Сфера',
#  'link': 'https://krasnodar.hh.ru/vacancy/37677528?query=python',
#  'name': 'Разработчик Python (middle/senior)',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a357f'),
#  'city': 'Москва',
#  'company_name': ' Akvelon',
#  'link': 'https://krasnodar.hh.ru/vacancy/37557027?query=python',
#  'name': 'Python-разработчик (full stack)',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3580'),
#  'city': 'Москва',
#  'company_name': ' Akvelon',
#  'link': 'https://krasnodar.hh.ru/vacancy/37557027?query=python',
#  'name': 'Python-разработчик (full stack)',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3581'),
#  'city': 'Минск, Площадь Ленина',
#  'company_name': 'Иностр. п. Admitad',
#  'link': 'https://krasnodar.hh.ru/vacancy/37396808?query=python',
#  'name': 'Senior Python Developer',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3582'),
#  'city': 'Минск, Восток и еще 1 ',
#  'company_name': ' СпурАйТи, ЧУП',
#  'link': 'https://krasnodar.hh.ru/vacancy/37457014?query=python',
#  'name': 'Middle/Senior Python Developer',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3583'),
#  'city': 'Минск',
#  'company_name': ' BP Mobile',
#  'link': 'https://krasnodar.hh.ru/vacancy/36677020?query=python',
#  'name': 'Python (Back-end) Developer',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3584'),
#  'city': 'Москва, Павелецкая',
#  'company_name': ' NPBFX Limited',
#  'link': 'https://krasnodar.hh.ru/vacancy/34649894?query=python',
#  'name': 'Full-Stack Web-Developer (Python / Odoo)',
#  'salary_currency': 'руб.',
#  'salary_max': '200000',
#  'salary_min': '100000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3585'),
#  'city': 'Киев',
#  'company_name': ' Ciklum',
#  'link': 'https://krasnodar.hh.ru/vacancy/37795242?query=python',
#  'name': 'Senior Python Developer for Paragon ID',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3586'),
#  'city': 'Москва, Комсомольская и еще 1 ',
#  'company_name': ' NetworkOptix',
#  'link': 'https://krasnodar.hh.ru/vacancy/30005963?query=python',
#  'name': 'Senior Python developer',
#  'salary_currency': 'USD',
#  'salary_max': None,
#  'salary_min': '4000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3587'),
#  'city': 'Киев, Олимпийская',
#  'company_name': 'ООО 4bill',
#  'link': 'https://krasnodar.hh.ru/vacancy/37466726?query=python',
#  'name': 'Middle Python Developer',
#  'salary_currency': 'USD',
#  'salary_max': '3000',
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3588'),
#  'city': 'Санкт-Петербург, Сенная площадь и еще 2 ',
#  'company_name': 'ООО Giant',
#  'link': 'https://krasnodar.hh.ru/vacancy/37314011?query=python',
#  'name': 'Senior Software Engineer (Python)',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3589'),
#  'city': 'Санкт-Петербург, Василеостровская и еще 1 ',
#  'company_name': 'АО Эшелон-Северо-Запад',
#  'link': 'https://krasnodar.hh.ru/vacancy/37334558?query=python',
#  'name': 'Разработчик WEB-приложений JS/Python',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a358a'),
#  'city': 'Москва',
#  'company_name': ' Profi-internet, школа востребованных интернет-профессий',
#  'link': 'https://krasnodar.hh.ru/vacancy/36906276?query=python',
#  'name': 'Программист по созданию и ведению обучающего курса по Python',
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': '150000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a358b'),
#  'city': 'Минск, Пушкинская',
#  'company_name': 'ИП Глебко С.К',
#  'link': 'https://krasnodar.hh.ru/vacancy/37468762?query=python',
#  'name': 'Преподаватель Python',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a358c'),
#  'city': 'Москва, Алтуфьево',
#  'company_name': 'ООО Акронис-Инфозащита',
#  'link': 'https://krasnodar.hh.ru/vacancy/36297018?query=python',
#  'name': 'Python developer',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a358d'),
#  'city': 'Киев',
#  'company_name': ' Profi-internet, школа востребованных интернет-профессий',
#  'link': 'https://krasnodar.hh.ru/vacancy/36924386?query=python',
#  'name': 'Программист для создания и ведения обучающего курса по Python',
#  'salary_currency': 'USD',
#  'salary_max': None,
#  'salary_min': '1800',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a358e'),
#  'city': 'Москва, Кутузовская',
#  'company_name': ' ДомКлик',
#  'link': 'https://krasnodar.hh.ru/vacancy/37580818?query=python',
#  'name': 'FullStack Developer (Python, JS)',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a358f'),
#  'city': 'Москва, Пролетарская и еще 1 ',
#  'company_name': 'ООО IT2G',
#  'link': 'https://krasnodar.hh.ru/vacancy/37672615?query=python',
#  'name': 'QA automation engineer (python) / специалист по автоматизированному '
#          'тестированию',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3590'),
#  'city': 'Минск, Площадь Ленина',
#  'company_name': 'Иностр. п. Admitad',
#  'link': 'https://krasnodar.hh.ru/vacancy/37396817?query=python',
#  'name': 'Team Lead/Python developer',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3591'),
#  'city': 'Москва, Комсомольская и еще 1 ',
#  'company_name': ' NetworkOptix',
#  'link': 'https://krasnodar.hh.ru/vacancy/35419959?query=python',
#  'name': 'QA Automation Engineer (Python)',
#  'salary_currency': 'USD',
#  'salary_max': None,
#  'salary_min': '3000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3592'),
#  'city': 'Москва, Менделеевская и еще 2 ',
#  'company_name': ' ИнПлат',
#  'link': 'https://krasnodar.hh.ru/vacancy/37608815?query=python',
#  'name': 'Разработчик Python/Team Lead',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3593'),
#  'city': 'Москва',
#  'company_name': ' Hexlet',
#  'link': 'https://krasnodar.hh.ru/vacancy/37741786?query=python',
#  'name': 'Наставник онлайн-курсов по программированию на Python',
#  'salary_currency': 'руб.',
#  'salary_max': '20000',
#  'salary_min': '12500',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3594'),
#  'city': 'Санкт-Петербург',
#  'company_name': 'ООО Телепорт',
#  'link': 'https://krasnodar.hh.ru/vacancy/37489646?query=python',
#  'name': 'Ведущий разработчик Python (Team Lead)',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3595'),
#  'city': 'Москва, Кутузовская',
#  'company_name': ' ДомКлик',
#  'link': 'https://krasnodar.hh.ru/vacancy/37748487?query=python',
#  'name': 'Python/Go Developer',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3596'),
#  'city': 'Санкт-Петербург',
#  'company_name': ' Big Data Solutions',
#  'link': 'https://krasnodar.hh.ru/vacancy/36633468?query=python',
#  'name': 'Python developer (Middle / Senior)',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3597'),
#  'city': 'Екатеринбург',
#  'company_name': ' NAUMEN',
#  'link': 'https://krasnodar.hh.ru/vacancy/36114431?query=python',
#  'name': 'Scala Developer (Java / C++ / С# / Python) (направление решений в '
#          'образовании)',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3598'),
#  'city': 'Москва, Кутузовская',
#  'company_name': ' ДомКлик',
#  'link': 'https://krasnodar.hh.ru/vacancy/37748464?query=python',
#  'name': 'Senior Python Developer',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a3599'),
#  'city': 'Минск',
#  'company_name': ' instinctools',
#  'link': 'https://krasnodar.hh.ru/vacancy/37762437?query=python',
#  'name': 'Senior/Lead Python Developer',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a359a'),
#  'city': 'Минск',
#  'company_name': 'ООО АлюсофтБел',
#  'link': 'https://krasnodar.hh.ru/vacancy/37226565?query=python',
#  'name': 'Senior Python Developer',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a359b'),
#  'city': 'Москва',
#  'company_name': 'ИП Хаюров Александр Александрович',
#  'link': 'https://krasnodar.hh.ru/vacancy/37350169?query=python',
#  'name': 'Full-Stack Developer (Python, Django / Node.JS, Angular 2+)',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a359c'),
#  'city': 'Минск',
#  'company_name': ' Sphere Consulting',
#  'link': 'https://krasnodar.hh.ru/vacancy/37678857?query=python',
#  'name': 'Senior Automation QA Engineer (Python/JS)',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a359d'),
#  'city': 'Санкт-Петербург',
#  'company_name': ' Genesys',
#  'link': 'https://krasnodar.hh.ru/vacancy/37343344?query=python',
#  'name': 'Senior Software Engineer (Java + JS or Java + Python)',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a359e'),
#  'city': 'Краснодар',
#  'company_name': 'ООО Виртуальный офис',
#  'link': 'https://krasnodar.hh.ru/vacancy/37246396?query=python',
#  'name': 'Ведущий разработчик PHP/Python (team lead)',
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': '150000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a359f'),
#  'city': 'Минск, Московская',
#  'company_name': ' Abiatec',
#  'link': 'https://krasnodar.hh.ru/vacancy/37394042?query=python',
#  'name': 'Python Developer',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a35a0'),
#  'city': 'Киев',
#  'company_name': ' Simple2B',
#  'link': 'https://krasnodar.hh.ru/vacancy/37793696?query=python',
#  'name': 'Trainee / Junior Python Web Developer',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a35a1'),
#  'city': 'Гомель',
#  'company_name': 'ООО Администрива',
#  'link': 'https://krasnodar.hh.ru/vacancy/37782758?query=python',
#  'name': 'Python Developer (Разработчик Python)',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a35a2'),
#  'city': 'Минск',
#  'company_name': 'ООО Умный код',
#  'link': 'https://krasnodar.hh.ru/vacancy/37738277?query=python',
#  'name': 'Python разработчик',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a35a3'),
#  'city': 'Киев',
#  'company_name': ' B2Broker Москва',
#  'link': 'https://krasnodar.hh.ru/vacancy/36100382?query=python',
#  'name': 'Python Developer',
#  'salary_currency': 'USD',
#  'salary_max': '3000',
#  'salary_min': '2000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a35a4'),
#  'city': 'Уральск',
#  'company_name': 'ТОО Алгоритмика Запад',
#  'link': 'https://krasnodar.hh.ru/vacancy/37652814?query=python',
#  'name': 'Преподаватель информатики Python',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a35a5'),
#  'city': 'Алматы, Москва',
#  'company_name': 'ТОО InformConsulting',
#  'link': 'https://krasnodar.hh.ru/vacancy/37652681?query=python',
#  'name': 'Python Developer',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a35a6'),
#  'city': 'Минск, Молодежная',
#  'company_name': 'ООО ЧейнАртСофт',
#  'link': 'https://krasnodar.hh.ru/vacancy/37648527?query=python',
#  'name': 'Python Developer',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a35a7'),
#  'city': 'Киев',
#  'company_name': ' Evergreen',
#  'link': 'https://krasnodar.hh.ru/vacancy/37536582?query=python',
#  'name': 'Программист Python',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a35a8'),
#  'city': 'Киев',
#  'company_name': 'ООО КФ.ЮА',
#  'link': 'https://krasnodar.hh.ru/vacancy/37536767?query=python',
#  'name': 'Python / Django developer',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a35a9'),
#  'city': 'Могилев',
#  'company_name': 'ИП Устименко Д. В.',
#  'link': 'https://krasnodar.hh.ru/vacancy/37446988?query=python',
#  'name': 'Test Automation Engineer in Python',
#  'salary_currency': 'бел.руб.',
#  'salary_max': None,
#  'salary_min': '3000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a35aa'),
#  'city': 'Минск',
#  'company_name': 'ООО Дуал Лаб Бел',
#  'link': 'https://krasnodar.hh.ru/vacancy/37168259?query=python',
#  'name': 'Junior Python Developer',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a35ab'),
#  'city': 'Минск, Площадь Якуба Коласа',
#  'company_name': 'ООО Фабрика инноваций и решений',
#  'link': 'https://krasnodar.hh.ru/vacancy/37440270?query=python',
#  'name': 'Python developer',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a35ac'),
#  'city': 'Брест',
#  'company_name': 'ИП Гречанюк В.С',
#  'link': 'https://krasnodar.hh.ru/vacancy/37406138?query=python',
#  'name': 'Python-программист (Разработчик)',
#  'salary_currency': 'бел.руб.',
#  'salary_max': '3000',
#  'salary_min': '600',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a35ad'),
#  'city': 'Гомель',
#  'company_name': 'ООО Старт Мэттер',
#  'link': 'https://krasnodar.hh.ru/vacancy/37393932?query=python',
#  'name': 'Python разработчик',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a35ae'),
#  'city': 'Киев',
#  'company_name': 'ООО Ejaw',
#  'link': 'https://krasnodar.hh.ru/vacancy/37374916?query=python',
#  'name': 'Python Developer (Fin-tech)',
#  'salary_currency': 'USD',
#  'salary_max': '900',
#  'salary_min': '500',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a35af'),
#  'city': 'Кострома',
#  'company_name': ' МониторЦен',
#  'link': 'https://krasnodar.hh.ru/vacancy/37532427?query=python',
#  'name': 'Программист Python',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a35b0'),
#  'city': 'Санкт-Петербург, Ладожская',
#  'company_name': ' Wargaming, Saint Petersburg (Lesta Studio)',
#  'link': 'https://krasnodar.hh.ru/vacancy/34380757?query=python',
#  'name': 'Gameplay/Client Side Programmer (C++, Python)',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a35b1'),
#  'city': 'Киев',
#  'company_name': ' DataArt',
#  'link': 'https://krasnodar.hh.ru/vacancy/36529110?query=python',
#  'name': 'Tech Lead with Python Experience, Financial Software Solutions',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a35b2'),
#  'city': 'Москва',
#  'company_name': 'ООО PROGNET',
#  'link': 'https://krasnodar.hh.ru/vacancy/37499121?query=python',
#  'name': 'Старший Python разработчик (Senior Developer, Lead, Архитектор)',
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': '150000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a35b3'),
#  'city': 'США',
#  'company_name': ' Architech',
#  'link': 'https://krasnodar.hh.ru/vacancy/37403518?query=python',
#  'name': 'Senior Back-End Engineer / Python',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a35b4'),
#  'city': 'Москва',
#  'company_name': ' Kokoc Group',
#  'link': 'https://krasnodar.hh.ru/vacancy/37101962?query=python',
#  'name': 'Программист Python',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a35b5'),
#  'city': 'Екатеринбург, Площадь 1905 года',
#  'company_name': ' JetStyle',
#  'link': 'https://krasnodar.hh.ru/vacancy/37789829?query=python',
#  'name': 'Python-разработчик',
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': '60000',
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efed56ac4bfbb6ef57a35b6'),
#  'city': 'Новосибирск, Красный проспект и еще 2 ',
#  'company_name': 'ООО Финтех Айкью',
#  'link': 'https://krasnodar.hh.ru/vacancy/37804296?query=python',
#  'name': 'Senior Python-разработчик',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# ...
#  'salary_max': 75000,
#  'salary_min': 45000,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b32'),
#  'city': 'Нижний Новгород, Горьковская',
#  'company_name': ' Neuro.net',
#  'link': 'https://krasnodar.hh.ru/vacancy/37384932?query=python',
#  'name': 'Разработчик Python',
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': 120000,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b33'),
#  'city': 'Москва, Павелецкая и еще 1 ',
#  'company_name': 'ООО Коннектом',
#  'link': 'https://krasnodar.hh.ru/vacancy/37391564?query=python',
#  'name': 'Разработчик Python / CV',
#  'salary_currency': 'руб.',
#  'salary_max': 150000,
#  'salary_min': 125000,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b34'),
#  'city': 'Москва',
#  'company_name': ' Bell Integrator',
#  'link': 'https://krasnodar.hh.ru/vacancy/37394789?query=python',
#  'name': 'Senior Python developer',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b35'),
#  'city': 'Семей',
#  'company_name': 'ТОО iMAS GROUP',
#  'link': 'https://krasnodar.hh.ru/vacancy/36586995?query=python',
#  'name': 'Junior Python Developer',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b36'),
#  'city': 'Москва',
#  'company_name': ' IPONWEB Ltd (UK)',
#  'link': 'https://krasnodar.hh.ru/vacancy/37429678?query=python',
#  'name': 'Middle/Senior Python developer',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b37'),
#  'city': 'Москва, Молодежная',
#  'company_name': ' zClick.pro',
#  'link': 'https://krasnodar.hh.ru/vacancy/37478640?query=python',
#  'name': 'Программист Python',
#  'salary_currency': 'руб.',
#  'salary_max': 200000,
#  'salary_min': 160000,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b38'),
#  'city': 'Москва, Водный стадион',
#  'company_name': ' Лаборатория Касперского',
#  'link': 'https://krasnodar.hh.ru/vacancy/37126451?query=python',
#  'name': 'Middle/Senior Python Developer',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b39'),
#  'city': 'Санкт-Петербург',
#  'company_name': ' ARRIVAL LTD',
#  'link': 'https://krasnodar.hh.ru/vacancy/37385752?query=python',
#  'name': 'Senior Python Developer (Vehicle Portal)',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b3a'),
#  'city': 'Омск',
#  'company_name': ' Effective',
#  'link': 'https://krasnodar.hh.ru/vacancy/37459307?query=python',
#  'name': 'Python / Django Developer (Middle)',
#  'salary_currency': 'руб.',
#  'salary_max': 80000,
#  'salary_min': 40000,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b3b'),
#  'city': 'Санкт-Петербург',
#  'company_name': 'ООО Кошелек.Ру',
#  'link': 'https://krasnodar.hh.ru/vacancy/37375334?query=python',
#  'name': 'Стажер-Автоматизатор тестирования (QA Automation) - Web, Python',
#  'salary_currency': 'руб.',
#  'salary_max': 25000,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b3c'),
#  'city': 'Казань, Суконная слобода и еще 1 ',
#  'company_name': ' INNOVA GROUP',
#  'link': 'https://krasnodar.hh.ru/vacancy/37368309?query=python',
#  'name': 'Программист Python',
#  'salary_currency': 'руб.',
#  'salary_max': 160000,
#  'salary_min': 110000,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b3d'),
#  'city': 'Москва',
#  'company_name': ' Neurus',
#  'link': 'https://krasnodar.hh.ru/vacancy/37372335?query=python',
#  'name': 'Middle Computer Vision / Machine Learning engineer (C++/Python)',
#  'salary_currency': 'руб.',
#  'salary_max': 250000,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b3e'),
#  'city': 'Москва, Белорусская',
#  'company_name': ' Авито',
#  'link': 'https://krasnodar.hh.ru/vacancy/37360289?query=python',
#  'name': 'Разработчик Python (Market intelligence)',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b3f'),
#  'city': 'Санкт-Петербург',
#  'company_name': 'ООО Тензор',
#  'link': 'https://krasnodar.hh.ru/vacancy/36854702?query=python',
#  'name': 'Python-developer',
#  'salary_currency': 'руб.',
#  'salary_max': 140000,
#  'salary_min': 87000,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b40'),
#  'city': 'Москва, Добрынинская',
#  'company_name': ' Онлайн-школа Тетрика',
#  'link': 'https://krasnodar.hh.ru/vacancy/37375195?query=python',
#  'name': 'Бэкенд разработчик на python',
#  'salary_currency': 'руб.',
#  'salary_max': 55000,
#  'salary_min': 35000,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b41'),
#  'city': 'Волгоград',
#  'company_name': ' Студия Кефир',
#  'link': 'https://krasnodar.hh.ru/vacancy/37355821?query=python',
#  'name': 'Программист Python',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b42'),
#  'city': 'Москва',
#  'company_name': ' Сбербанк для экспертов',
#  'link': 'https://krasnodar.hh.ru/vacancy/37365018?query=python',
#  'name': 'Python разработчик',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b43'),
#  'city': 'Москва, Улица 1905 года',
#  'company_name': ' UBIC',
#  'link': 'https://krasnodar.hh.ru/vacancy/37363176?query=python',
#  'name': 'Python-разработчик',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b44'),
#  'city': 'Москва, Курская',
#  'company_name': ' АКРИХИН',
#  'link': 'https://krasnodar.hh.ru/vacancy/37344000?query=python',
#  'name': 'Web-разработчик Python',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b45'),
#  'city': 'Томск',
#  'company_name': ' Sibedge',
#  'link': 'https://krasnodar.hh.ru/vacancy/36943545?query=python',
#  'name': 'Python разработчик',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b46'),
#  'city': 'Санкт-Петербург, Горьковская',
#  'company_name': ' Доктор Веб',
#  'link': 'https://krasnodar.hh.ru/vacancy/36865263?query=python',
#  'name': 'Инженер-программист / Developer (Python)',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b47'),
#  'city': 'Москва',
#  'company_name': 'ООО ИЦ АЙ-ТЕКО',
#  'link': 'https://krasnodar.hh.ru/vacancy/37362576?query=python',
#  'name': 'Разработчик Python (металлургия)',
#  'salary_currency': 'руб.',
#  'salary_max': 150000,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b48'),
#  'city': 'Тюмень',
#  'company_name': ' Creative',
#  'link': 'https://krasnodar.hh.ru/vacancy/37349987?query=python',
#  'name': 'Python-разработчик',
#  'salary_currency': 'руб.',
#  'salary_max': 120000,
#  'salary_min': 50000,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b49'),
#  'city': 'Москва, Бибирево и еще 1 ',
#  'company_name': ' ЛогЛаб',
#  'link': 'https://krasnodar.hh.ru/vacancy/37341909?query=python',
#  'name': 'Full stack web-разработчик (Python)',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b4a'),
#  'city': 'Новосибирск, Березовая роща',
#  'company_name': ' People group, центр подбора и развития персонала',
#  'link': 'https://krasnodar.hh.ru/vacancy/37351431?query=python',
#  'name': 'Python Django разработчик',
#  'salary_currency': 'руб.',
#  'salary_max': 120000,
#  'salary_min': 80000,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b4b'),
#  'city': 'Санкт-Петербург, Спортивная',
#  'company_name': ' Риалвеб, Интернет-агентство',
#  'link': 'https://krasnodar.hh.ru/vacancy/29755826?query=python',
#  'name': 'Python разработчик',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b4c'),
#  'city': 'Москва',
#  'company_name': ' Агентство 21 век, КЦ',
#  'link': 'https://krasnodar.hh.ru/vacancy/37347670?query=python',
#  'name': 'QA automation engineer (Python)/ Специалист по автоматизированному '
#          'тестированию',
#  'salary_currency': 'руб.',
#  'salary_max': 180000,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b4d'),
#  'city': 'Гомель',
#  'company_name': 'ООО ОпенМайГейм',
#  'link': 'https://krasnodar.hh.ru/vacancy/36859517?query=python',
#  'name': 'Senior Python Backend Developer',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b4e'),
#  'city': 'Тюмень',
#  'company_name': ' Студия 42',
#  'link': 'https://krasnodar.hh.ru/vacancy/37328519?query=python',
#  'name': 'Программист Python',
#  'salary_currency': 'руб.',
#  'salary_max': 110000,
#  'salary_min': 90000,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b4f'),
#  'city': 'Москва, Аэропорт',
#  'company_name': ' Mail.Ru Group, Почтовые сервисы',
#  'link': 'https://krasnodar.hh.ru/vacancy/37316538?query=python',
#  'name': 'Python разработчик в инфраструктурную команду (Маруся)',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b50'),
#  'city': 'Москва',
#  'company_name': ' Group-IB',
#  'link': 'https://krasnodar.hh.ru/vacancy/37333560?query=python',
#  'name': 'Разработчик Python',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b51'),
#  'city': 'Москва',
#  'company_name': ' Лента, федеральная розничная сеть, IT ',
#  'link': 'https://krasnodar.hh.ru/vacancy/37332838?query=python',
#  'name': 'Python Developer',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b52'),
#  'city': 'Нижний Новгород',
#  'company_name': 'ПАО МегаФон, IT',
#  'link': 'https://krasnodar.hh.ru/vacancy/35695141?query=python',
#  'name': 'Python Developer',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b53'),
#  'city': 'Минск, Молодежная и еще 1 ',
#  'company_name': ' RocketData',
#  'link': 'https://krasnodar.hh.ru/vacancy/36863372?query=python',
#  'name': 'Senior Python Developer/Team Lead',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b54'),
#  'city': 'Петрозаводск',
#  'company_name': 'ООО Комплексные медицинские информационные системы',
#  'link': 'https://krasnodar.hh.ru/vacancy/37388522?query=python',
#  'name': 'Backend-разработчик (Python, Django)',
#  'salary_currency': 'руб.',
#  'salary_max': 80000,
#  'salary_min': 40000,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b55'),
#  'city': 'Томск',
#  'company_name': ' Sibedge',
#  'link': 'https://krasnodar.hh.ru/vacancy/35554372?query=python',
#  'name': 'Senior Python Developer',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b56'),
#  'city': 'Томск',
#  'company_name': ' Sibedge',
#  'link': 'https://krasnodar.hh.ru/vacancy/35599856?query=python',
#  'name': 'Senior Python Developer',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b57'),
#  'city': 'Москва',
#  'company_name': ' Group-IB',
#  'link': 'https://krasnodar.hh.ru/vacancy/37333564?query=python',
#  'name': 'Python программист',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b58'),
#  'city': 'Минск, Петровщина',
#  'company_name': ' SoftTeco',
#  'link': 'https://krasnodar.hh.ru/vacancy/37332357?query=python',
#  'name': 'Python Developer (Middle/Senior)',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b59'),
#  'city': 'Москва, Белорусская',
#  'company_name': ' McKinsey & Company',
#  'link': 'https://krasnodar.hh.ru/vacancy/34251157?query=python',
#  'name': 'Data Scientist / Senior Data Scientist (Python)',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b5a'),
#  'city': 'Москва',
#  'company_name': ' Virtuozzo',
#  'link': 'https://krasnodar.hh.ru/vacancy/37400087?query=python',
#  'name': 'Middleware Developer (C/C++/Python/Golang)',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b5b'),
#  'city': 'США',
#  'company_name': ' Ground01 LLC',
#  'link': 'https://krasnodar.hh.ru/vacancy/37403682?query=python',
#  'name': 'Python Архитектор/Разработчик',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b5c'),
#  'city': 'Москва',
#  'company_name': 'ООО АК Альянс',
#  'link': 'https://krasnodar.hh.ru/vacancy/37365169?query=python',
#  'name': 'Разработчик Python (Computer Vision/Graphics)',
#  'salary_currency': 'руб.',
#  'salary_max': 170000,
#  'salary_min': 100000,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b5d'),
#  'city': 'Москва',
#  'company_name': 'ООО ЭИР ЛАБС РУС',
#  'link': 'https://krasnodar.hh.ru/vacancy/37456378?query=python',
#  'name': 'Python QA Engineer',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b5e'),
#  'city': 'Москва',
#  'company_name': 'ООО Инфософт Сервис',
#  'link': 'https://krasnodar.hh.ru/vacancy/37376893?query=python',
#  'name': 'Разработчик Python/программист Python',
#  'salary_currency': 'руб.',
#  'salary_max': 100000,
#  'salary_min': 60000,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b5f'),
#  'city': 'Нур-Султан',
#  'company_name': 'ТОО ЦЕНТР БЕСПИЛОТНЫХ СИСТЕМ КАЗАХСТАНА',
#  'link': 'https://krasnodar.hh.ru/vacancy/37027359?query=python',
#  'name': 'Инженер-программист C++, Python',
#  'salary_currency': 'KZT',
#  'salary_max': None,
#  'salary_min': 500000,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b60'),
#  'city': 'Москва',
#  'company_name': 'ООО Интернет Лид',
#  'link': 'https://krasnodar.hh.ru/vacancy/37435108?query=python',
#  'name': 'Python/Django разработчик',
#  'salary_currency': 'руб.',
#  'salary_max': 40000,
#  'salary_min': 30000,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b61'),
#  'city': 'Москва, Деловой центр и еще 2 ',
#  'company_name': 'ИП Смелов Владимир Павлович',
#  'link': 'https://krasnodar.hh.ru/vacancy/37342385?query=python',
#  'name': 'Программист (C# / Python / Java / NodeJS)',
#  'salary_currency': 'руб.',
#  'salary_max': 140000,
#  'salary_min': 70000,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b62'),
#  'city': 'Москва, Красные ворота',
#  'company_name': ' НТЦ Система',
#  'link': 'https://krasnodar.hh.ru/vacancy/37365034?query=python',
#  'name': 'Разработчик Python',
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': 60000,
#  'site': 'hh.ru'}
# {'_id': ObjectId('5efedfc7c4bfbb6ef57a3b63'),
#  'city': 'Киев',
#  'company_name': 'ООО SourceX',
#  'link': 'https://krasnodar.hh.ru/vacancy/37655063?query=python',
#  'name': 'Back-end Engineer (Python + AWS)',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'hh.ru'}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-8ffd277bc594> in <module>
# ----> 1 find_vacancy_by_salary(salary, vacancys_data)
#
# <ipython-input-45-eb066df2a4e4> in find_vacancy_by_salary(salary, vacancys_data)
#       5
#       6     write_vacancys(vacancys_data)
# ----> 7     vacancys_salary_more = vacancys.find({'$or':[{'salary_min':{'$gt':salary}}, {'salary_max':{'$gt':salary}}]})
#       8
#       9     return vacancys_salary_more
#
# NameError: name 'vacancys' is not defined

# %% [markdown]
# 3) Написать функцию, которая будет добавлять в вашу базу данных только новые вакансии с сайта

# %%
def new_vacations(data):
    return db.vacancys.update(data, {"upsert":True})
# Out:
#   File "<ipython-input-69-b07b919cb69b>", line 2
#     return db.vacancys.update(for data in vacancys_data, {"upsert":True})
#                                 ^
# SyntaxError: invalid syntax

# %%
new_vacations(vacancys_data)
# Out:
# /Users/gleb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning: update is deprecated. Use replace_one, update_one or update_many instead.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-8ff2c9797dca> in <module>
# ----> 1 new_vacations(vacancys_data)
#
# <ipython-input-67-a2285db9232e> in new_vacations(vacancys_data)
#       1 def new_vacations(vacancys_data):
# ----> 2     return db.vacancys.update(vacancys_data, {"upsert":True})
#       3
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pymongo/collection.py in update(self, spec, document, upsert, manipulate, multi, check_keys, **kwargs)
#    3195         warnings.warn("update is deprecated. Use replace_one, update_one or "
#    3196                       "update_many instead.", DeprecationWarning, stacklevel=2)
# -> 3197         common.validate_is_mapping("spec", spec)
#    3198         common.validate_is_mapping("document", document)
#    3199         if document:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pymongo/common.py in validate_is_mapping(option, value)
#     472         raise TypeError("%s must be an instance of dict, bson.son.SON, or "
#     473                         "any other type that inherits from "
# --> 474                         "collections.Mapping" % (option,))
#     475
#     476
#
# TypeError: spec must be an instance of dict, bson.son.SON, or any other type that inherits from collections.Mapping
